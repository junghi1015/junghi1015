# %%
t = int(input())

for i in range(t):
    a = list(map(int, input().split()))
    print(a[0] + a[1])
# Out:
# 1
# 1 2
# 3

# %%
a = map(int, input().split())
# Out:
# 12,3

# %%
print(a)

# %%
type(a)
# Out:
# list

# %%
for i in list(5):
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-43036b14d9fb> in <module>
# ----> 1 for i in list(5):
#       2     print(i)
#
# TypeError: 'int' object is not iterable

# %%
n = int(input())

for i in range(n):
# Out:
# 33

# %%
type(n)
# Out:
# list

# %%
n
# Out:
# ['5']

# %%
a = []

# %%
import time
from PIL import Image
import requests
from io import BytesIO
from selenium import webdriver as wd

# request.get 요청

import pandas as pd

driver = wd.Chrome("C:\chromedriver")#,options=options)
url="http://news.jtbc.joins.com/section/index.aspx?scode=20"
driver.get(url)
time.sleep(1)

script_cnt = driver.find_elements_by_xpath('/html/body/div[4]/div/div[1]/div[2]/form/div[3]/div/div[2]/div[2]/ul/li')

t = []

for i in range(1,len(script_cnt)+1):

    driver.find_element_by_xpath('/html/body/div[4]/div/div[1]/div[2]/form/div[3]/div/div[2]/div[2]/ul/li[%d]/dl/dt/a'%(i)).click()
    br_cnt = driver.find_elements_by_xpath('/html/body/div[5]/div/div[1]/div[2]/form/div[7]/div[1]/div[2]/div[1]/br')
 
    time.sleep(1)
    time.sleep(1)
    time.sleep(1)
    time.sleep(1)

    b = driver.find_element_by_xpath('/html/body/div[5]/div/div[1]/div[2]/form/div[7]/div[1]/div[2]/div[1]') 
    t.append(b.text)

#     for j in range(1, len(br_cnt)):

#         a = driver.find_element_by_xpath('/html/body/div[5]/div/div[1]/div[2]/form/div[7]/div[1]/div[2]/div[1]/text()[%d]'%(j))

#         print(a)

#         print(a)

#         t.append(a.text)

    driver.back()
    time.sleep(1)

# %%
t
# Out:
# ['우리나라 가계가 대출과 카드사용 등으로 진 빚(신용)이 또 역대 최대 기록을 갈아치웠다.\n\n특히 2분기(4~6월)에만 주택담보대출이 15조 원 가까이 급증했고, 돈까지 빌려 주식을 사는 이른바 \'빚투\' 열풍에 증권사의 2분기 신용공여액도 사상 최대로 늘었다.\n\n한국은행이 19일 발표한 \'2분기 가계신용(잠정)\' 통계에 따르면 2분기 말 현재 가계신용 잔액은 1천637조3천억 원으로 통계 작성을 시작한 2002년 4분기 이래 가장 많았다. 2002년 이전 가계신용 규모는 지금보다 훨씬 작았기 때문에 사상 최대 기록인 셈이다.\n\n가계신용은 가계가 은행·보험사·대부업체·공적 금융기관 등에서 받은 대출에 결제 전 카드 사용금액(판매신용)까지 더한 \'포괄적 가계 빚(부채)\'을 말한다.\n\n2분기 가계신용은 1분기 말보다 25조9천억 원(1.6%) 늘었다. 증가 폭이 1분기(11조1천억 원)의 2배를 웃돌고, 작년 4분기(27조8천억 원)와 비슷한 수준이다.\n\n작년 2분기보다는 80조5천억 원(5.2%) 불었다. 작년 동기 대비 기준으로 2018년 4분기(86조1천억 원) 이후 1년 6개월 내 최대 증가액이다.\n\n가계신용 중 판매신용을 제외한 가계대출 잔액은 1천545조7천억 원으로 집계됐다. 역시 역대 최대 기록이고, 2분기 증가액(23조9천억 원)은 2017년 4분기(28조7천억 원) 이후 2년 반만에 가장 많았다.\n\n가계대출 가운데 주택담보대출(잔액 873조 원)은 2분기에만 14조8천억 원 늘었다. 2분기 주택담보대출 증가 폭은 1분기(15조3천억 원)보다 다소 줄었지만, 작년 2분기(8조4천억 원)의 거의 두 배 규모다.\n\n신용대출을 포함한 기타대출(잔액 672조7천억 원)도 2분기에 9조1천억 원이나 증가했다. 증가액이 작년 4분기(10조5천억 원)에는 미치지 못하지만, 1분기(1조9천억 원)와 비교하면 4배로 뛰었다.\n\n기타대출 중 증권사의 신용공여액은 2분기에 7조9천억 원이나 늘었다. 이 증가폭은 사상 최대
# ...

# %%
t1 = pd.DataFrame(t)

# %%
import pandas as pd
t1.to_csv("C:\\rtest\\t1.csv", sep=',', na_rep='NaN', encoding='euc-kr')

# %%
line_t = ''
for i in t:
    line_t += i

# %%
f = open('test.txt', 'w', encoding='utf-8')
f.write(line_t)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-c39cd74e712d> in <module>
#       1 import pandas as pd
#       2
# ----> 3 t1 = pd.DataFrame(line_t)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     507                 )
#     508             else:
# --> 509                 raise ValueError("DataFrame constructor not properly called!")
#     510
#     511         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
line_t
# Out:
# '우리나라 가계가 대출과 카드사용 등으로 진 빚(신용)이 또 역대 최대 기록을 갈아치웠다.\n\n특히 2분기(4~6월)에만 주택담보대출이 15조 원 가까이 급증했고, 돈까지 빌려 주식을 사는 이른바 \'빚투\' 열풍에 증권사의 2분기 신용공여액도 사상 최대로 늘었다.\n\n한국은행이 19일 발표한 \'2분기 가계신용(잠정)\' 통계에 따르면 2분기 말 현재 가계신용 잔액은 1천637조3천억 원으로 통계 작성을 시작한 2002년 4분기 이래 가장 많았다. 2002년 이전 가계신용 규모는 지금보다 훨씬 작았기 때문에 사상 최대 기록인 셈이다.\n\n가계신용은 가계가 은행·보험사·대부업체·공적 금융기관 등에서 받은 대출에 결제 전 카드 사용금액(판매신용)까지 더한 \'포괄적 가계 빚(부채)\'을 말한다.\n\n2분기 가계신용은 1분기 말보다 25조9천억 원(1.6%) 늘었다. 증가 폭이 1분기(11조1천억 원)의 2배를 웃돌고, 작년 4분기(27조8천억 원)와 비슷한 수준이다.\n\n작년 2분기보다는 80조5천억 원(5.2%) 불었다. 작년 동기 대비 기준으로 2018년 4분기(86조1천억 원) 이후 1년 6개월 내 최대 증가액이다.\n\n가계신용 중 판매신용을 제외한 가계대출 잔액은 1천545조7천억 원으로 집계됐다. 역시 역대 최대 기록이고, 2분기 증가액(23조9천억 원)은 2017년 4분기(28조7천억 원) 이후 2년 반만에 가장 많았다.\n\n가계대출 가운데 주택담보대출(잔액 873조 원)은 2분기에만 14조8천억 원 늘었다. 2분기 주택담보대출 증가 폭은 1분기(15조3천억 원)보다 다소 줄었지만, 작년 2분기(8조4천억 원)의 거의 두 배 규모다.\n\n신용대출을 포함한 기타대출(잔액 672조7천억 원)도 2분기에 9조1천억 원이나 증가했다. 증가액이 작년 4분기(10조5천억 원)에는 미치지 못하지만, 1분기(1조9천억 원)와 비교하면 4배로 뛰었다.\n\n기타대출 중 증권사의 신용공여액은 2분기에 7조9천억 원이나 늘었다. 이 증가폭은 사상 최대 
# ...

# %%
n = map(int, input())

def d(n):
    if n < 10:
        
    elif n

# %%
n,x = map(int,input().split(','))
# Out:
# 1 2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-108-071df8fc4160> in <module>
# ----> 1 n,x = map(int,input().split(','))
#
# ValueError: invalid literal for int() with base 10: '1 2'

# %%
n
# Out:
# 1

# %%
x
# Out:
# 2
